# %% [markdown]
# # Introduction
#
# Download a dataset from darts github page:
# - https://github.com/unit8co/darts/blob/master/datasets/AirPassengers.csv
# - https://raw.githubusercontent.com/unit8co/darts/master/datasets/AirPassengers.csv

# %% [markdown]
# # SSL Error (MyDartsDataset().load())

# %%
# !ls certificates
# Out:
# darts_air_passengers_caadmin.netskope.com
# darts_datasets_caadmin.netskope.com

# %%
from darts.datasets import AirPassengersDataset
import os

# add the certificate
certificate_path = "certificates/darts_datasets_caadmin.netskope.com"
os.environ["REQUESTS_CA_BUNDLE"] = certificate_path

try:
    series = AirPassengersDataset().load()
    display(series.head(2))
except BaseException as ex:
    print(str(ex))
# Out:
# <TimeSeries (DataArray) (Month: 2, component: 1, sample: 1)>
# array([[[112.]],
#
#        [[118.]]])
# Coordinates:
#   * Month      (Month) datetime64[ns] 1949-01-01 1949-02-01
#   * component  (component) object '#Passengers'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
import darts.datasets

print([i for i in dir(darts.datasets) if i[0]!='_' if i[0].upper() == i[0]])
# Out:
# ['AirPassengersDataset', 'AusBeerDataset', 'AustralianTourismDataset', 'DatasetLoaderCSV', 'DatasetLoaderMetadata', 'ETTh1Dataset', 'ETTh2Dataset', 'ETTm1Dataset', 'ETTm2Dataset', 'ElectricityDataset', 'EnergyDataset', 'ExchangeRateDataset', 'GasRateCO2Dataset', 'HeartRateDataset', 'ILINetDataset', 'IceCreamHeaterDataset', 'List', 'MonthlyMilkDataset', 'MonthlyMilkIncompleteDataset', 'Path', 'SunspotsDataset', 'TaylorDataset', 'TemperatureDataset', 'TimeSeries', 'TrafficDataset', 'USGasolineDataset', 'UberTLCDataset', 'WeatherDataset', 'WineDataset', 'WoolyDataset']

# %%
from darts.datasets import AusBeerDataset
import os

# add the certificate
certificate_path = "certificates/darts_datasets_caadmin.netskope.com"
os.environ["REQUESTS_CA_BUNDLE"] = certificate_path

try:
    series = AusBeerDataset().load()
    display(series.head(2))
except BaseException as ex:
    print(str(ex))
# Out:
# <TimeSeries (DataArray) (date: 2, component: 1, sample: 1)>
# array([[[284.]],
#
#        [[213.]]])
# Coordinates:
#   * date       (date) datetime64[ns] 1956-01-01 1956-04-01
#   * component  (component) object 'Y'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %% [markdown]
# # Read github csv directly using pandas

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/unit8co/darts/master/datasets/AirPassengers.csv"
df = pd.read_csv(url)
df.iloc[[0,1,-2,-1]]
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 142  1960-11          390
# 143  1960-12          432

# %% [markdown]
# # requests.get and verify=False

# %%
import requests
url = "https://raw.githubusercontent.com/unit8co/darts/master/datasets/AirPassengers.csv"
try:
    response = requests.get(url,verify=False)
    data_str = response.content
    print(data_str[:10])
except requests.exceptions.SSLError as e:
    print(str(e))
# Out:
# b'Month,#Pas'
# C:\Users\a126291\venv\py39darts\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'raw.githubusercontent.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %% [markdown]
# # Using certificate netscope.com file

# %%
import requests
import os
import io

note = r'''
Open website in Chrome and click on top left lock sign
Connection is Secure > Certificate if Valid > Details > select top hierarchy > Export
and save inside folder 'certificate'

'''

certificate_path = "certificates/caadmin.netskope.com"
assert os.path.isfile(certificate_path), "File not found"

url = "https://raw.githubusercontent.com/unit8co/darts/master/datasets/AirPassengers.csv"

response = requests.get(url, verify=certificate_path)

if response.status_code == 200:
    data = response.content
    df = pd.read_csv(io.StringIO(data.decode('utf-8')))
    display(df.head())
else:
    print("Failed to download the data. Status code:", response.status_code)
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %% [markdown]
# # Good way: Alternative

# %%
import os
import requests
import pandas as pd
import io

# add the certificate
certificate_path = "certificates/caadmin.netskope.com"
os.environ["REQUESTS_CA_BUNDLE"] = certificate_path

# get the data
url = "https://raw.githubusercontent.com/unit8co/darts/master/datasets/AirPassengers.csv"
response = requests.get(url)

if response.status_code == 200:
    data = response.content
    df = pd.read_csv(io.StringIO(data.decode('utf-8')))
    print(df.head())
else:
    print("Failed to download the data. Status code:", response.status_code)
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121
